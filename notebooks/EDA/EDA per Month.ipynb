# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import re
from os import listdir

# %%
PATH = r'C:\Users\heylu\Documents\github\A Study Case About Mental Health Tweets in Pandemic Times\data'

# %%
df = pd.DataFrame()
for f in listdir(PATH + '\\' + '2018'):
    dataset_from_files_in_path = pd.read_csv(PATH + '\\' + '2018' + '\\' + f)
    df = pd.concat([df, dataset_from_files_in_path])
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df
# Out:
#                    user_id      conversation_id        date      time  \
# 0               1430944412   958912747621806080  2018-01-31  23:59:49
# 1       940021578624065537   958912695411052545  2018-01-31  23:59:36
# 2                139421250   958912686120685573  2018-01-31  23:59:34
# 3       937692691621646336   958912558601293824  2018-01-31  23:59:04
# 4                176789934   958912363855532032  2018-01-31  23:58:17
# ...                    ...                  ...         ...       ...
# 90001   752884910327734272  1068716714735689728  2018-12-01  00:01:35
# 90002            261219891  1068716591435665408  2018-12-01  00:01:05
# 90003           1646809729  1068716526851801088  2018-12-01  00:00:50
# 90004           3436824867  1068716412837994496  2018-12-01  00:00:23
# 90005  1029551318552195072  1068711650117763073  2018-12-01  00:00:22
#
#                                                    tweet
# 0      Insônia com ansiedade te faz gerar muitas para...
# ...

# %%
frequency = df
frequency['quantidade'] = 1
frequency = frequency.groupby('date').sum()[['quantidade']]
fig = px.bar(frequency)
fig
# Out:
# <div>                            <div id="8e1c9632-cad2-45b5-aeff-a73fc791eff6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e1c9632-cad2-45b5-aeff-a73fc791eff6")) {                    Plotly.newPlot(                        "8e1c9632-cad2-45b5-aeff-a73fc791eff6",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2018-01-01", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-06", "2018-01-07", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-0
# ...

# %%
frequency.index = pd.to_datetime(frequency.index)
frequency_per_month = frequency.groupby(pd.Grouper(freq='M')).sum()
fig = px.bar(frequency_per_month)
fig
# Out:
# <div>                            <div id="26e04d72-47d1-4885-ab30-052211389106" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26e04d72-47d1-4885-ab30-052211389106")) {                    Plotly.newPlot(                        "26e04d72-47d1-4885-ab30-052211389106",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2018-01-31T00:00:00", "2018-02-28T00:00:00", "2018-03-31T00:00:00", "2018-04-30T00:00:00", "2018-05-31T00:00:00", "2018-06-30T00:00:00", "2018-07-31T00:00:00", 
# ...

# %%
frequency.reset_index(inplace=True)
frequency['dia_da_semana'] = frequency['date'].dt.day_name()
dias_traduzidos = {'Monday': 'Segunda', 
                   'Tuesday': 'Terça',
                  'Wednesday': 'Quarta',
                  'Thursday': 'Quinta',
                  'Friday': 'Sexta',
                  'Saturday': 'Sábado',
                  'Sunday': 'Domingo'}
frequency['dia_da_semana'] = frequency['dia_da_semana'].apply(lambda x: dias_traduzidos[x])
dia_da_semana = frequency.groupby('dia_da_semana').sum()
fig = px.bar(dia_da_semana)
fig
# Out:
# <div>                            <div id="a4d52e8f-1904-40d1-bc13-abba521e5e2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4d52e8f-1904-40d1-bc13-abba521e5e2a")) {                    Plotly.newPlot(                        "a4d52e8f-1904-40d1-bc13-abba521e5e2a",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>dia_da_semana=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Domingo", "Quarta", "Quinta", "Segunda", "Sexta", "S\u00e1bado", "Ter\u00e7a"], "xaxis": "x", "y": [131146.0, 160893.0, 152320.0, 155818.0, 134629.0, 1
# ...

# %%
fig = px.line(data_frame=frequency, y='quantidade', x='date')
fig
# Out:
# <div>                            <div id="0e8b4b68-fa29-46ef-9793-46061abe31d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e8b4b68-fa29-46ef-9793-46061abe31d5")) {                    Plotly.newPlot(                        "0e8b4b68-fa29-46ef-9793-46061abe31d5",                        [{"hovertemplate": "date=%{x}<br>quantidade=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-01-02T00:00:00", "2018-01-03T00:00:00", "2018-01-04T00:00:00", "2018-01-05T00:00:00", "2018-01-06T00:00:00", "2018-01-07T00:00:00", "2018-01-08T00:00:00", "2018-01-09T00:00:00", "2018-01-10T00:00:00", "2018-01-11
# ...

# %%
df = pd.DataFrame()
for f in listdir(PATH + '\\' + '2019'):
    dataset_from_files_in_path = pd.read_csv(PATH + '\\' + '2019' + '\\' + f)
    df = pd.concat([df, dataset_from_files_in_path])
df.drop(columns='Unnamed: 0', inplace=True)
df.drop(columns='Unnamed: 0.1', inplace=True)

# %%
frequency = df
frequency['quantidade'] = 1
frequency = frequency.groupby('date').sum()[['quantidade']]

# %%
fig = px.bar(frequency)
fig
# Out:
# <div>                            <div id="01b9f737-db56-448c-a87a-28b4622678fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01b9f737-db56-448c-a87a-28b4622678fe")) {                    Plotly.newPlot(                        "01b9f737-db56-448c-a87a-28b4622678fe",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-01-01", "2019-01-02", "2019-01-03", "2019-01-04", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-0
# ...

# %%
frequency.index = pd.to_datetime(frequency.index)
frequency_per_month = frequency.groupby(pd.Grouper(freq='M')).sum()
fig = px.bar(frequency_per_month)
fig
# Out:
# <div>                            <div id="a64f3bd0-2354-437e-9774-5a4c08942483" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a64f3bd0-2354-437e-9774-5a4c08942483")) {                    Plotly.newPlot(                        "a64f3bd0-2354-437e-9774-5a4c08942483",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2019-01-31T00:00:00", "2019-02-28T00:00:00", "2019-03-31T00:00:00", "2019-04-30T00:00:00", "2019-05-31T00:00:00", "2019-06-30T00:00:00", "2019-07-31T00:00:00", 
# ...

# %%
frequency.reset_index(inplace=True)
frequency['dia_da_semana'] = frequency['date'].dt.day_name()
dias_traduzidos = {'Monday': 'Segunda', 
                   'Tuesday': 'Terça',
                  'Wednesday': 'Quarta',
                  'Thursday': 'Quinta',
                  'Friday': 'Sexta',
                  'Saturday': 'Sábado',
                  'Sunday': 'Domingo'}
frequency['dia_da_semana'] = frequency['dia_da_semana'].apply(lambda x: dias_traduzidos[x])
dia_da_semana = frequency.groupby('dia_da_semana').sum()
fig = px.bar(dia_da_semana)
fig
# Out:
# <div>                            <div id="9d7c1ee4-1c68-4fab-b565-b9cc12e06797" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d7c1ee4-1c68-4fab-b565-b9cc12e06797")) {                    Plotly.newPlot(                        "9d7c1ee4-1c68-4fab-b565-b9cc12e06797",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>dia_da_semana=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Domingo", "Quarta", "Quinta", "Segunda", "Sexta", "S\u00e1bado", "Ter\u00e7a"], "xaxis": "x", "y": [191748.0, 256883.0, 235567.0, 244099.0, 216050.0, 1
# ...

# %%
df = pd.DataFrame()
for f in listdir(PATH + '\\' + '2020'):
    dataset_from_files_in_path = pd.read_csv(PATH + '\\' + '2020' + '\\' + f)
    df = pd.concat([df, dataset_from_files_in_path])
df.drop(columns='Unnamed: 0', inplace=True)

# %%
frequency = df
frequency['quantidade'] = 1
frequency = frequency.groupby('date').sum()[['quantidade']]
fig = px.bar(frequency)
fig
# Out:
# <div>                            <div id="2204c1b3-322b-4ffe-9ace-414a11cbe5bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2204c1b3-322b-4ffe-9ace-414a11cbe5bc")) {                    Plotly.newPlot(                        "2204c1b3-322b-4ffe-9ace-414a11cbe5bc",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-01-01", "2020-01-02", "2020-01-03", "2020-01-04", "2020-01-05", "2020-01-06", "2020-01-07", "2020-01-08", "2020-01-09", "2020-01-10", "2020-01-11", "2020-0
# ...

# %%
frequency.index = pd.to_datetime(frequency.index)
frequency_per_month = frequency.groupby(pd.Grouper(freq='M')).sum()
fig = px.bar(frequency_per_month)
fig
# Out:
# <div>                            <div id="98e78430-9521-4465-ba1e-b33047cb157f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98e78430-9521-4465-ba1e-b33047cb157f")) {                    Plotly.newPlot(                        "98e78430-9521-4465-ba1e-b33047cb157f",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2020-01-31T00:00:00", "2020-02-29T00:00:00", "2020-03-31T00:00:00", "2020-04-30T00:00:00", "2020-05-31T00:00:00", "2020-06-30T00:00:00", "2020-07-31T00:00:00", 
# ...

# %%
frequency.reset_index(inplace=True)
frequency['dia_da_semana'] = frequency['date'].dt.day_name()
dias_traduzidos = {'Monday': 'Segunda', 
                   'Tuesday': 'Terça',
                  'Wednesday': 'Quarta',
                  'Thursday': 'Quinta',
                  'Friday': 'Sexta',
                  'Saturday': 'Sábado',
                  'Sunday': 'Domingo'}
frequency['dia_da_semana'] = frequency['dia_da_semana'].apply(lambda x: dias_traduzidos[x])
dia_da_semana = frequency.groupby('dia_da_semana').sum()
fig = px.bar(dia_da_semana)
fig
# Out:
# <div>                            <div id="90847846-2f4b-439c-98bd-ccdd4d47de13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90847846-2f4b-439c-98bd-ccdd4d47de13")) {                    Plotly.newPlot(                        "90847846-2f4b-439c-98bd-ccdd4d47de13",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>dia_da_semana=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Domingo", "Quarta", "Quinta", "Segunda", "Sexta", "S\u00e1bado", "Ter\u00e7a"], "xaxis": "x", "y": [382185.0, 516580.0, 494323.0, 497456.0, 431794.0, 3
# ...

# %%
df = pd.DataFrame()
for f in listdir(PATH + '\\' + '2021'):
    dataset_from_files_in_path = pd.read_csv(PATH + '\\' + '2021' + '\\' + f)
    df = pd.concat([df, dataset_from_files_in_path])
df.drop(columns='Unnamed: 0', inplace=True)

# %%
frequency = df
frequency['quantidade'] = 1
frequency = frequency.groupby('date').sum()[['quantidade']]
fig = px.bar(frequency)
fig
# Out:
# <div>                            <div id="6a57f7df-eb7f-4b08-a849-a7d283c53151" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a57f7df-eb7f-4b08-a849-a7d283c53151")) {                    Plotly.newPlot(                        "6a57f7df-eb7f-4b08-a849-a7d283c53151",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2021-01-01", "2021-01-02", "2021-01-03", "2021-01-04", "2021-01-05", "2021-01-06", "2021-01-07", "2021-01-08", "2021-01-09", "2021-01-10", "2021-01-11", "2021-0
# ...

# %%
frequency.index = pd.to_datetime(frequency.index)
frequency_per_month = frequency.groupby(pd.Grouper(freq='M')).sum()
fig = px.bar(frequency_per_month)
fig
# Out:
# <div>                            <div id="fb8d5a4f-143a-4847-8836-25627c08222e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb8d5a4f-143a-4847-8836-25627c08222e")) {                    Plotly.newPlot(                        "fb8d5a4f-143a-4847-8836-25627c08222e",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["2021-01-31T00:00:00", "2021-02-28T00:00:00", "2021-03-31T00:00:00", "2021-04-30T00:00:00"], "xaxis": "x", "y": [429541.0, 406924.0, 507763.0, 444897.0], "yaxis"
# ...

# %%
frequency.reset_index(inplace=True)
frequency['dia_da_semana'] = frequency['date'].dt.day_name()
dias_traduzidos = {'Monday': 'Segunda', 
                   'Tuesday': 'Terça',
                  'Wednesday': 'Quarta',
                  'Thursday': 'Quinta',
                  'Friday': 'Sexta',
                  'Saturday': 'Sábado',
                  'Sunday': 'Domingo'}
frequency['dia_da_semana'] = frequency['dia_da_semana'].apply(lambda x: dias_traduzidos[x])
dia_da_semana = frequency.groupby('dia_da_semana').sum()
fig = px.bar(dia_da_semana)
fig
# Out:
# <div>                            <div id="b0f256bb-e26f-4aef-bf60-0527b157b8d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0f256bb-e26f-4aef-bf60-0527b157b8d2")) {                    Plotly.newPlot(                        "b0f256bb-e26f-4aef-bf60-0527b157b8d2",                        [{"alignmentgroup": "True", "hovertemplate": "variable=quantidade<br>dia_da_semana=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "quantidade", "marker": {"color": "#636efa"}, "name": "quantidade", "offsetgroup": "quantidade", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Domingo", "Quarta", "Quinta", "Segunda", "Sexta", "S\u00e1bado", "Ter\u00e7a"], "xaxis": "x", "y": [244663.0, 258009.0, 269982.0, 283998.0, 246126.0, 2
# ...
