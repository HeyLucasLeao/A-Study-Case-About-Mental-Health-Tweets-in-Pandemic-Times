# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
dataframe = pd.read_csv(r'C:\Users\heylu\Documents\github\Sentimental Analysis -  A Study Case About Mental Health in Pandemic Times\data\cleaned\time_series_data.csv', index_col='date')

# %%
dataframe.asfreq('D').fillna(0)
# Out:
#             qtd
# date
# 2014-03-06  0.0
# 2014-03-07  0.0
# 2014-03-08  0.0
# 2014-03-09  0.0
# 2014-03-10  0.0
# ...         ...
# 2021-04-26  0.0
# 2021-04-27  0.0
# 2021-04-28  0.0
# 2021-04-29  0.0
# 2021-04-30  0.0
#
# [2613 rows x 1 columns]

# %%
fig = px.line(dataframe, 
labels={'value': 'Tweets', 'date': 'Ano'}, 
title= 'Frequência de Tweets sobre Saúde Mental - Sem Retweets & URL',
height=800,
width=800)

fig.update_layout(showlegend=False, hovermode='x')

fig.update_traces(hovertemplate="%{y}", name='Tweets')

# %%
fig = px.bar(data_frame=freq.sort_values('Qtd',ascending=True), 
y='Hashtag', 
x='Qtd', 
height=600,
title= 'Frequência de Hashtag com mais de 100 menções - Sem Retweets & URL')

fig

# %%
freq = pd.read_csv(r'C:\Users\heylu\Documents\github\Sentimental Analysis -  A Study Case About Mental Health in Pandemic Times\data\cleaned\freq.csv')

# %%
freq = freq.drop(columns='Unnamed: 0').rename(columns={'0': 'Hashtag'})
freq = freq.value_counts()[freq.value_counts() > 100]
freq = pd.DataFrame(freq).reset_index().rename(columns={0: 'Qtd'})
